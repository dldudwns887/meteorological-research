# %%
import pandas as pd
import numpy as np
import xarray
import matplotlib.pyplot as plt
# import Basemap

data_path_1 = "/home/papalio/test_research/python_edu/class0/example_0913"
data_path_2 = "/home/papalio/test_research/python_edu/class0/example_0914"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import xarray
#       4 import matplotlib.pyplot as plt
# ----> 5 import Basemap
#       7 data_path_1 = "/home/papalio/test_research/python_edu/class0/example_0913"
#       8 data_path_2 = "/home/papalio/test_research/python_edu/class0/example_0914"
#
# ModuleNotFoundError: No module named 'Basemap'

# %%
# 공간분포
file = "SSP_data.nc"
ds = xarray.open_dataset(data_path_1+file)
ds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/test_app/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/anaconda3/envs/test_app/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/papalio/test_research/python_edu/class0/example_0913SSP_data.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '17a3b5f9-079d-4be9-abb6-b9356fdb11ae']
#
# During handling of the above exception, another exception occurred:
#
# ...
